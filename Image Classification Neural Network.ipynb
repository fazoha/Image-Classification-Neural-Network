# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=data.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
#print(train_labels[0])

# %%
#plt.imshow(train_images[7])

# %%
train_images=train_images/255.0 #shrinking the data

# %%
test_images=test_images/255.0

# %%
plt.imshow(train_images[1])

# %%
#print(train_images[1])

# %%
model= keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),
                         keras.layers.Dense(128,activation='relu'),
                         keras.layers.Dense(10,activation="softmax")])
# Out:
# 2024-01-08 15:11:20.160971: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-01-08 15:11:20.160995: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-01-08 15:11:20.161004: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-01-08 15:11:20.161403: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-08 15:11:20.161820: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(train_images,train_labels,epochs=9)
# Out:
# Epoch 1/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4767 - accuracy: 0.8397
# Epoch 2/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4791 - accuracy: 0.8397
# Epoch 3/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4832 - accuracy: 0.8394
# Epoch 4/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4894 - accuracy: 0.8396
# Epoch 5/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5026 - accuracy: 0.8368
# Epoch 6/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5081 - accuracy: 0.8383
# Epoch 7/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5262 - accuracy: 0.8339
# Epoch 8/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5266 - accuracy: 0.8354
# Epoch 9/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5420 - accuracy: 0.8332

# %%
test_loss,test_accuracy=model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5235 - accuracy: 0.8252

# %%
print("Tested Accuracy: ",test_accuracy)
# Out:
# Tested Accuracy:  0.8252000212669373

# %%
prediction=model.predict(test_images)
for i in range(10):
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.title("Prediction "+ class_names[np.argmax(prediction[i])])
    plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step
